# %%
# open the file
fin = open('words.txt')

# take each line from the file and output each word
for line in fin:
    word = line.strip()
    print(word)

# %% [markdown]
# Print all of the words that are longer than 20 letters:

# %%
fin = open('words.txt')
for line in fin:
    word = line.strip()
    if len(word) > 20:
        print(word)
# Out:
# counterdemonstrations
# hyperaggressivenesses
# microminiaturizations

# %% [markdown]
# How many words start or end with the letter 'x'?

# %%
fin = open('words.txt')
for line in fin:
    word = line.strip()
    if word[0] == 'x' or word[-1] == 'x':
        print(word)
# Out:
# aboideaux
# aboiteaux
# addax
# adieux
# admix
# affix
# afflux
# aftertax
# annex
# antefix
# anthelix
# anthrax
# anticlimax
# antitax
# apex
# appendix
# apteryx
# aruspex
# auspex
# aviatrix
# bandbox
# bandeaux
# bateaux
# batteaux
# beaux
# beeswax
# bemix
# biconvex
# biflex
# bijoux
# bollix
# bollox
# bombyx
# borax
# box
# broadax
# bureaux
# calix
# calx
# calyx
# carapax
# carex
# cashbox
# caudex
# cervix
# chamoix
# chapeaux
# chateaux
# chatterbox
# cicatrix
# cimex
# circumflex
# climax
# coalbox
# coannex
# coax
# coccyx
# codex
# commix
# complex
# conflux
# convex
# cortex
# coteaux
# couteaux
# cowpox
# cox
# crucifix
# crux
# culex
# curtalax
# cylix
# desex
# dewax
# dex
# diplex
# duplex
# earwax
# eaux
# efflux
# epicalyx
# equinox
# ex
# executrix
# fabliaux
# fax
# feedbox
# firebox
# fix
# flambeaux
# flax
# flex
# flummox
# flux
# fornix
# fowlpox
# fox
# galax
# gearbox
# googolplex
# gox
# hallux
# hapax
# haruspex
# hatbox
# helix
# hellbox
# heretrix
# heritrix
# hex
# hoax
# hotbox
# hyrax
# ibex
# icebox
# ilex
# immix
# index
# infix
# influx
# intermix
# interrex
# intersex
# jambeaux
# jeux
# jinx
# jukebox
# kex
# kylix
# larynx
# latex
# lax
# lex
# lockbox
# lox
# lummox
# lux
# lynx
# mailbox
# manteaux
# mastix
# matchbox
# matrix
# meninx
# microlux
# middlesex
# milieux
# millilux
# minimax
# minx
# mirex
# mix
# morceaux
# murex
# narthex
# nix
# nonorthodox
# nontax
# octuplex
# onyx
# oratrix
# orthodox
# oryx
# outbox
# outfox
# outjinx
# overlax
# overmix
# overtax
# ox
# packwax
# panchax
# paradox
# parallax
# pax
# paxwax
# pegbox
# pemphix
# pendaflex
# perplex
# phalanx
# pharynx
# phenix
# phlox
# phoenix
# pickax
# pillbox
# pix
# plateaux
# poleax
# pollex
# pontifex
# postbox
# postfix
# pox
# precieux
# prefix
# premix
# pretax
# prex
# priedieux
# princox
# prolix
# pyx
# quincunx
# radix
# rax
# reaffix
# reannex
# rectrix
# redox
# refix
# reflex
# reflux
# reindex
# relax
# remex
# remix
# reseaux
# rewax
# rex
# rondeaux
# rouleaux
# roux
# salpinx
# saltbox
# sandbox
# sardonyx
# saucebox
# sax
# scolex
# sex
# silex
# simplex
# six
# smallpox
# smilax
# snuffbox
# soapbox
# sonovox
# soundbox
# sox
# spadix
# sphinx
# spinifex
# storax
# styrax
# subfix
# subindex
# suffix
# superfix
# supersex
# supertax
# surtax
# sweatbox
# swinepox
# syntax
# syrinx
# tableaux
# tax
# teabox
# tectrix
# tektronix
# telex
# thorax
# toadflax
# tonneaux
# toolbox
# tortrix
# transfix
# triplex
# trousseaux
# trumeaux
# tubifex
# tux
# unbox
# undertax
# unfix
# unisex
# unorthodox
# unsex
# varix
# vernix
# vertex
# vex
# volvox
# vortex
# vox
# wax
# woadwax
# woodbox
# woodwax
# workbox
# xanthate
# xanthates
# xanthein
# xantheins
# xanthene
# xanthenes
# xanthic
# xanthin
# xanthine
# xanthines
# xanthins
# xanthoma
# xanthomas
# xanthomata
# xanthone
# xanthones
# xanthous
# xebec
# xebecs
# xenia
# xenial
# xenias
# xenic
# xenogamies
# xenogamy
# xenogenies
# xenogeny
# xenolith
# xenoliths
# xenon
# xenons
# xenophobe
# xenophobes
# xenophobia
# xerarch
# xeric
# xerosere
# xeroseres
# xeroses
# xerosis
# xerotic
# xerus
# xeruses
# xi
# xiphoid
# xiphoids
# xis
# xu
# xylan
# xylans
# xylem
# xylems
# xylene
# xylenes
# xylic
# xylidin
# xylidine
# xylidines
# xylidins
# xylocarp
# xylocarps
# xyloid
# xylol
# xylols
# xylophone
# xylophones
# xylophonist
# xylophonists
# xylose
# xyloses
# xylotomies
# xylotomy
# xylyl
# xylyls
# xyst
# xyster
# xysters
# xysti
# xystoi
# xystos
# xysts
# xystus
# zax
